# %%
import pandas as pd
df=pd.read_csv('./source/equinox2020.csv')

# %%
df_india=df[df['NGA']=='Deccan']

# %%
df_india[df_india['Variable']=='Impeachment']
# Out:
#           NGA   Polity                  Section  \
# 15236  Deccan  InDecIA  Institutional Variables
# 17387  Deccan  InSataL  Institutional Variables
#
#                                    Subsection     Variable Value.From  \
# 15236  Limits on Power of the Chief Executive  Impeachment    unknown
# 17387  Limits on Power of the Chief Executive  Impeachment    unknown
#
#       Value.To Date.From Date.To Fact.Type Value.Note Date.Note
# 15236      NaN       NaN     NaN    simple     simple       NaN
# 17387      NaN       NaN     NaN    simple     simple       NaN

# %%
df_lat=df[df['NGA']=='Latium']
df_lat[1000:1100]
# Out:
#           NGA   Polity                      Section  \
# 25023  Latium  ItPapM2            Warfare variables
# 25024  Latium  ItPapM2            Warfare variables
# 25025  Latium  ItPapM2            Warfare variables
# 25026  Latium  ItPapM2            Warfare variables
# 25027  Latium  ItPapM2            Warfare variables
# ...       ...      ...                          ...
# 25118  Latium  ItPapRn  Social Complexity variables
# 25119  Latium  ItPapRn  Social Complexity variables
# 25120  Latium  ItPapRn  Social Complexity variables
# 25121  Latium  ItPapRn  Social Complexity variables
# 25122  Latium  ItPapRn  Social Complexity variables
#
#                         Subsection                          Variable  \
# 25023        Military Technologies                            Bronze
# 25024        Military Technologies                              Iron
# 25025        Military Technologies                             Steel
# ...
