# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Save as pickle:

# %%
df_pops = pd.read_pickle('./populations.pkl')
df_pops
# Out:
#                           NGA    Pop_Min  Pop_Max From_Year To_Year
# Polity
# MxAztec       Basin of Mexico  3000000.0  4000000         0       0
# MxPostM       Basin of Mexico   700000.0   800000         0       0
# MxToltc       Basin of Mexico   150000.0   200000         0       0
# USKameh     Big Island Hawaii    60000.0   180000      1800       0
# Hawaii2     Big Island Hawaii     3500.0     7000      1200       0
# ...                       ...        ...      ...       ...     ...
# MxAlb3B      Valley of Oaxaca     7245.0     9660         0       0
# MxAlb5*      Valley of Oaxaca     8127.0    10836         0       0
# YeHmyr1  Yemeni Coastal Plain   300000.0   500000         0       0
# EtAksm1  Yemeni Coastal Plain   500000.0   600000         0       0
# YeHmyr2  Yemeni Coastal Plain   300000.0   500000         0       0
#
# [348 rows x 5 columns]

# %%
df_china = df_pops[df_pops['NGA']=='Middle Yellow River Valley'].sort_values('From_Year')
df_india = df_pops[df_pops['NGA']=='Deccan'].sort_values('From_Year')
df_japan = df_pops[df_pops['NGA']=='Kansai'].sort_values('From_Year')

# %%
plt.figure(figsize=(10, 8))
sns.lineplot(data=df_china, x='From_Year', y='Pop_Min', label='China')
sns.lineplot(data=df_india, x='From_Year', y='Pop_Min', label='India')
sns.lineplot(data=df_japan, x='From_Year', y='Pop_Min', label='Japan')
# Out:
# <AxesSubplot:xlabel='From_Year', ylabel='Pop_Min'>

# %%
df_japan
# Out:
#             NGA     Pop_Min  Pop_Max From_Year To_Year
# Polity
# JpJomo6  Kansai       400.0     1000         0       0
# JpJomo5  Kansai       400.0     1000         0       0
# JpJomo3  Kansai       400.0     1000         0       0
# JpYayoi  Kansai      1500.0     3000         0       0
# JpKofun  Kansai    150000.0   200000       250     400
# JpKofun  Kansai    200000.0   300000       401     500
# JpKofun  Kansai    250000.0   350000       500     537
# JpAsuka  Kansai   1500000.0  2000000       538     600
# JpAsuka  Kansai   2000000.0  3000000       601     709
# JpNara*  Kansai   5800000.0  6400000       700       0
# JpHeian  Kansai   4000000.0        0       800       0
# JpHeian  Kansai   4400000.0  5600000       900       0
# JpHeian  Kansai   4500000.0  5000000      1000       0
# JpHeian  Kansai   5500000.0  6300000      1100       0
# JpKamak  Kansai   5500000.0  6300000      1200       0
# JpKamak  Kansai   5700000.0  6200000      1300       0
# ...
