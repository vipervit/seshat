# %% [markdown]
# ### Contains list of all variables categories

# %%
import pandas as pd

# %%
df=pd.read_csv('./source/equinox2020.csv')
df
# Out:
#                         NGA   Polity                          Section  \
# 0               Kachi Plain  AfDurrn                General variables
# 1               Kachi Plain  AfDurrn                General variables
# 2               Kachi Plain  AfDurrn                General variables
# 3               Kachi Plain  AfDurrn                General variables
# 4               Kachi Plain  AfDurrn                General variables
# ...                     ...      ...                              ...
# 47472  Yemeni Coastal Plain  YeZiyad  Religion and Normative Ideology
# 47473  Yemeni Coastal Plain  YeZiyad  Religion and Normative Ideology
# 47474  Yemeni Coastal Plain  YeZiyad  Religion and Normative Ideology
# 47475  Yemeni Coastal Plain  YeZiyad  Religion and Normative Ideology
# 47476  Yemeni Coastal Plain  YeZiyad  Religion and Normative Ideology
#
#                            Subsection  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 47472  Moralizing Supernatural Powers
# 47473  Moralizing Supernatural Powers
# 47474  Moralizing Supernatural Powers
# 47475  Moralizing Supernatural Powers
# 47476  Moralizing Supernatural Powers
#
#                                        Variable          Value.From Value.To  \
# 0                                            RA        Stephen Dean      NaN
# 1                                            RA      Alice Williams      NaN
# 2                                 Original name      Durrani Empire      NaN
# 3                             Alternative names     Sadozai Kingdom      NaN
# 4                             Alternative names  Last Afghan Empire      NaN
# ...                                         ...                 ...      ...
# 47472     Moralizing religion adopted by elites             present      NaN
# 47473  Moralizing religion adopted by commoners             present      NaN
# 47474       Moralizing enforcement in afterlife             present      NaN
# 47475       Moralizing enforcement in this life             present      NaN
# 47476         Moralizing enforcement is agentic             present      NaN
#
#       Date.From Date.To Fact.Type Value.Note Date.Note
# 0           NaN     NaN   complex       list       NaN
# 1           NaN     NaN   complex       list       NaN
# 2           NaN     NaN    simple     simple       NaN
# 3           NaN     NaN   complex       list       NaN
# 4           NaN     NaN   complex       list       NaN
# ...         ...     ...       ...        ...       ...
# 47472       NaN     NaN    simple     simple       NaN
# 47473       NaN     NaN    simple     simple       NaN
# 47474       NaN     NaN    simple     simple       NaN
# 47475       NaN     NaN    simple     simple       NaN
# 47476       NaN     NaN    simple     simple       NaN
#
# [47477 rows x 12 columns]

# %%
sections=df['Section'].unique()
sections
# Out:
# array(['General variables', 'Social Complexity variables',
#        'Warfare variables', 'Institutional Variables', 'Social Mobility',
#        'Religion and Normative Ideology'], dtype=object)

# %%
instvars = df[df['Section'] =='Institutional Variables']['Variable'].unique()
instvars
# Out:
# array(['RA', 'Constraint on executive by government',
#        'Constraint on executive by non-government', 'Impeachment'],
#       dtype=object)

# %%
subsections=df['Subsection'].unique()
subsections
# Out:
# array([nan, 'Social Scale', 'Hierarchical Complexity', 'Professions',
#        'Bureaucracy characteristics', 'Law',
#        'Specialized Buildings: polity owned', 'Information',
#        'Military Technologies', 'Status', 'Deification of Rulers',
#        'Normative Ideological Aspects of Equity and Prosociality',
#        'Moralizing Supernatural Powers',
#        'Limits on Power of the Chief Executive',
#        'Largest scale collective ritual of the official cult',
#        'Most widespread collective ritual of the official cult',
#        'Most frequent collective ritual of the official cult',
#        'Most euphoric collective ritual of the official cult',
#        'Most dysphoric collective ritual of the official cult',
#        'Normative ideological Aspects of Equity and Prosociality'],
#       dtype=object)

# %%
df_params=df[['Section', 'Subsection', 'Variable']].sort_values(['Section', 'Subsection', 'Variable']).drop_duplicates()
df_params.reset_index(drop=True, inplace=True)
df_params
# Out:
#                Section Subsection                    Variable
# 0    General variables        NaN           Alternative names
# 1    General variables        NaN                     Capital
# 2    General variables        NaN    Degree of centralization
# 3    General variables        NaN                    Duration
# 4    General variables        NaN                    Language
# ..                 ...        ...                         ...
# 193  Warfare variables        NaN  Stone walls (non-mortared)
# 194  Warfare variables        NaN                      Swords
# 195  Warfare variables        NaN       Tension siege engines
# 196  Warfare variables        NaN                   War clubs
# 197  Warfare variables        NaN               Wood bark etc
#
# [198 rows x 3 columns]

# %%
df_params.describe()
# Out:
#                   Section             Subsection  Variable
# count                 198                    134       198
# unique                  6                     19       135
# top     Warfare variables  Military Technologies  Duration
# freq                  100                     49         6

# %%
df_params['Section'].unique()
# Out:
# array(['General variables', 'Institutional Variables',
#        'Religion and Normative Ideology', 'Social Complexity variables',
#        'Social Mobility', 'Warfare variables'], dtype=object)

# %%
df_gen = df_params[df_params['Section']=='General variables']

# %%
df_instit = df_params[df_params['Section']=='Institutional Variables']

# %%
df_religion = df_params[df_params['Section']=='Religion and Normative Ideology']

# %%
df_socomplex = df_params[df_params['Section']=='Social Complexity variables']

# %%
df_somobil = df_params[df_params['Section']=='Social Mobility']

# %%
df_warfare = df_params[df_params['Section']=='Warfare variables']

# %%
df_gen
# Out:
#               Section Subsection                                 Variable
# 0   General variables        NaN                        Alternative names
# 1   General variables        NaN                                  Capital
# 2   General variables        NaN                 Degree of centralization
# 3   General variables        NaN                                 Duration
# 4   General variables        NaN                                 Language
# 5   General variables        NaN                            Original name
# 6   General variables        NaN                                Peak Date
# 7   General variables        NaN                                       RA
# 8   General variables        NaN                   Supra-polity relations
# 9   General variables        NaN                     Supracultural entity
# 10  General variables        NaN                  preceding (quasi)polity
# 11  General variables        NaN  relationship to preceding (quasi)polity
# 12  General variables        NaN      scale of supra-cultural interaction
# 13  General variables        NaN                 succeeding (quasi)polity

# %%
df_instit
# Out:
#                     Section                              Subsection  \
# 14  Institutional Variables  Limits on Power of the Chief Executive
# 15  Institutional Variables  Limits on Power of the Chief Executive
# 16  Institutional Variables  Limits on Power of the Chief Executive
# 17  Institutional Variables                                     NaN
#
#                                      Variable
# 14      Constraint on executive by government
# 15  Constraint on executive by non-government
# 16                                Impeachment
# 17                                         RA

# %%
df_religion
# Out:
#                             Section  \
# 18  Religion and Normative Ideology
# 19  Religion and Normative Ideology
# 20  Religion and Normative Ideology
# 21  Religion and Normative Ideology
# 22  Religion and Normative Ideology
# 23  Religion and Normative Ideology
# 24  Religion and Normative Ideology
# 25  Religion and Normative Ideology
# 26  Religion and Normative Ideology
# 27  Religion and Normative Ideology
# 28  Religion and Normative Ideology
# 29  Religion and Normative Ideology
# 30  Religion and Normative Ideology
# 31  Religion and Normative Ideology
# 32  Religion and Normative Ideology
# 33  Religion and Normative Ideology
# 34  Religion and Normative Ideology
# 35  Religion and Normative Ideology
# 36  Religion and Normative Ideology
# 37  Religion and Normative Ideology
# 38  Religion and Normative Ideology
# 39  Religion and Normative Ideology
# 40  Religion and Normative Ideology
# 41  Religion and Normative Ideology
# 42  Religion and Normative Ideology
# 43  Religion and Normative Ideology
#
#                                            Subsection  \
# 18                              Deification of Rulers
# 19                              Deification of Rulers
# 20                              Deification of Rulers
# 21                              Deification of Rulers
# 22                              Deification of Rulers
# 23                     Moralizing Supernatural Powers
# 24                     Moralizing Supernatural Powers
# 25                     Moralizing Supernatural Powers
# 26                     Moralizing Supernatural Powers
# 27                     Moralizing Supernatural Powers
# 28                     Moralizing Supernatural Powers
# 29                     Moralizing Supernatural Powers
# 30                     Moralizing Supernatural Powers
# 31                     Moralizing Supernatural Powers
# 32                     Moralizing Supernatural Powers
# 33  Normative Ideological Aspects of Equity and Pr...
# 34  Normative Ideological Aspects of Equity and Pr...
# 35  Normative Ideological Aspects of Equity and Pr...
# 36  Normative Ideological Aspects of Equity and Pr...
# 37  Normative Ideological Aspects of Equity and Pr...
# 38  Normative ideological Aspects of Equity and Pr...
# 39  Normative ideological Aspects of Equity and Pr...
# 40  Normative ideological Aspects of Equity and Pr...
# 41  Normative ideological Aspects of Equity and Pr...
# 42  Normative ideological Aspects of Equity and Pr...
# 43                                                NaN
#
#                                             Variable
# 18             Ideological reinforcement of equality
# 19  Ideological thought equates elites and commoners
# 20  Ideological thought equates rulers and commoners
# 21                                   Rulers are gods
# 22                    Rulers are legitimated by gods
# 23                          Moral concern is primary
# 24               Moralizing enforcement in afterlife
# 25               Moralizing enforcement in this life
# 26                 Moralizing enforcement is agentic
# 27                 Moralizing enforcement is certain
# 28                Moralizing enforcement is targeted
# 29                  Moralizing enforcement of rulers
# 30                        Moralizing norms are broad
# 31          Moralizing religion adopted by commoners
# 32             Moralizing religion adopted by elites
# 33             Ideological reinforcement of equality
# 34  Ideological thought equates elites and commoners
# 35  Ideological thought equates rulers and commoners
# 36                  Ideology reinforces prosociality
# 37                        production of public goods
# 38             Ideological reinforcement of equality
# 39  Ideological thought equates elites and commoners
# 40  Ideological thought equates rulers and commoners
# 41                  Ideology reinforces prosociality
# 42                        production of public goods
# 43                                                RA

# %%
df_socomplex
# Out:
#                         Section                           Subsection  \
# 44  Social Complexity variables          Bureaucracy characteristics
# 45  Social Complexity variables          Bureaucracy characteristics
# 46  Social Complexity variables          Bureaucracy characteristics
# 47  Social Complexity variables          Bureaucracy characteristics
# 48  Social Complexity variables              Hierarchical Complexity
# 49  Social Complexity variables              Hierarchical Complexity
# 50  Social Complexity variables              Hierarchical Complexity
# 51  Social Complexity variables              Hierarchical Complexity
# 52  Social Complexity variables                          Information
# 53  Social Complexity variables                          Information
# 54  Social Complexity variables                          Information
# 55  Social Complexity variables                          Information
# 56  Social Complexity variables                          Information
# 57  Social Complexity variables                          Information
# 58  Social Complexity variables                          Information
# 59  Social Complexity variables                          Information
# 60  Social Complexity variables                          Information
# 61  Social Complexity variables                          Information
# 62  Social Complexity variables                          Information
# 63  Social Complexity variables                          Information
# 64  Social Complexity variables                          Information
# 65  Social Complexity variables                          Information
# 66  Social Complexity variables                          Information
# 67  Social Complexity variables                          Information
# 68  Social Complexity variables                          Information
# 69  Social Complexity variables                          Information
# 70  Social Complexity variables                          Information
# 71  Social Complexity variables                          Information
# 72  Social Complexity variables                          Information
# 73  Social Complexity variables                          Information
# 74  Social Complexity variables                          Information
# 75  Social Complexity variables                          Information
# 76  Social Complexity variables                                  Law
# 77  Social Complexity variables                                  Law
# 78  Social Complexity variables                                  Law
# 79  Social Complexity variables                                  Law
# 80  Social Complexity variables                          Professions
# 81  Social Complexity variables                          Professions
# 82  Social Complexity variables                          Professions
# 83  Social Complexity variables                         Social Scale
# 84  Social Complexity variables                         Social Scale
# 85  Social Complexity variables                         Social Scale
# 86  Social Complexity variables  Specialized Buildings: polity owned
# 87  Social Complexity variables  Specialized Buildings: polity owned
# 88  Social Complexity variables  Specialized Buildings: polity owned
# 89  Social Complexity variables  Specialized Buildings: polity owned
# 90  Social Complexity variables  Specialized Buildings: polity owned
# 91  Social Complexity variables  Specialized Buildings: polity owned
# 92  Social Complexity variables  Specialized Buildings: polity owned
# 93  Social Complexity variables  Specialized Buildings: polity owned
# 94  Social Complexity variables  Specialized Buildings: polity owned
# 95  Social Complexity variables                                  NaN
#
#                                 Variable
# 44                    Examination system
# 45                 Full-time bureaucrats
# 46                       Merit promotion
# 47      Specialized government buildings
# 48                 Administrative levels
# 49                       Military levels
# 50                      Religious levels
# 51                  Settlement hierarchy
# 52                              Articles
# 53                              Calendar
# 54                              Couriers
# 55                               Fiction
# 56                         Foreign coins
# 57                General postal service
# 58                               History
# 59                      Indigenous coins
# 60      Lists tables and classifications
# 61                      Mnemonic devices
# 62                  Non-phonetic writing
# 63                    Nonwritten records
# 64                        Paper currency
# 65                            Philosophy
# 66           Phonetic alphabetic writing
# 67                       Postal stations
# 68                  Practical literature
# 69                       Precious metals
# 70                  Religious literature
# 71                          Sacred Texts
# 72                 Scientific literature
# 73                                Script
# 74                                Tokens
# 75                       Written records
# 76                                Courts
# 77                     Formal legal code
# 78                                Judges
# 79                  Professional Lawyers
# 80        Professional military officers
# 81               Professional priesthood
# 82                 Professional soldiers
# 83                     Polity Population
# 84                      Polity territory
# 85  Population of the largest settlement
# 86                               Bridges
# 87                                Canals
# 88                     Mines or quarries
# 89                                 Ports
# 90                                 Roads
# 91         drinking water supply systems
# 92                    food storage sites
# 93                    irrigation systems
# 94                               markets
# 95                                    RA
